# %% [markdown]
# # Indian Tourism Exploratory analysis

# %% [markdown]
# ## Introduction

# %%
Tourism is the largest service industry in india.Tourism in india is important for the country's economy and is growing rapidly.
India provides the facility to tourists of international origin to understand and experience cultural diversity of the country.
India is a land of beautiful hill stations,parks,temples etc.Here we have done the analysis on the tourism in india.

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load the data set

# %%
df=pd.read_csv('E:/tourism.csv')

# %%
df
# Out:
#                                        Name      Region             Type  \
# 0                                     Kufri  North East     Hill Station
# 1                              Wilson Hills        West     Hill Station
# 2                               Paithalmala       South     Hill Station
# 3                                   Ponmudi       South     Hill Station
# 4                                 Ranipuram       South     Hill Station
# 5                                    Manali       North     Hill Station
# 6                                   Gulmarg       North     Hill Station
# 7                               Dharamshala  North East     Hill Station
# 8                                 Lansdowne  North East     Hill Station
# 9                                      Auli  North East     Hill Station
# 10                               Darjeeling  North East     Hill Station
# 11         Jawaharlal Nehru Biological Park        East  Zoological Park
# 12               Tata Steel Zoological Park        East  Zoological Park
# 13              Nandankanan Zoological Park        East  Zoological Park
# 14  Padmaja Naidu Himalayan Zoological Park        East  Zoological Park
# 15                 National zooligical Park       North  Zoological Park
# 16                    Nehru Zoological Park  South West  Zoological Park
# 17                               Mysore Zoo  South West  Zoological Park
# 18             Arignar Anna Zoological Park  South East  Zoological Park
# 19                             Gopalpur Zoo       North  Zoological Park
# 20                      Gulabh Bagh and Zoo  North West  Zoological Park
# 21                             Chattbir Zoo  North West  Zoological Park
# 22           Pt. G.B Pant High Altitude Zoo       North  Zoological Park
# 23                              Alipore Zoo  North East  Zoological Park
# 24            Indira Gandhi Zoological Park       South  Zoological Park
# 25                             Agonda beach        West            Beach
# 26                            Palolem Beach        East            Beach
# 27                         Radhanagar Beach  South East            Beach
# 28                         Cavelossim beach        West            Beach
# 29                               Puri Beach        East            Beach
# 30                           Candolim Beach        West            Beach
# 31                        Dhanushkodi Beach        West            Beach
# 32                              Colva Beach        West            Beach
# 33                             Utorda Beach        West            Beach
# 34                             Marari Beach        West            Beach
# 35                          Elephanta Beach        East            Beach
# 36                    The Konark Sun Temple        East           Temple
# 37                           Somnath Temple        West           Temple
# 38                         Kedarnath Temple       North           Temple
# 39                     Ramnathaswamy Temple       South           Temple
# 40                      Vaishno Devi Mandir       North           Temple
# 41                     Siddhivinayak Temple        West           Temple
# 42                         Badrinath Temple       North           Temple
# 43                          Gangotri Temple       North           Temple
# 44                  Kashi Vishwanath Temple  North East           Temple
# 45                    Lord Jagannath Temple  South East           Temple
# 46                         Yamunotri Temple       North           Temple
# 47                         Meenakshi Temple       South           Temple
# 48                     Amarnath Cave Temple       North           Temple
#
#     airport_dist(km)  railway_dist(km)  Elevation(m)  rating
# 0               20.0            100.00       2210.00     7.0
# 1              122.0             60.00        750.00     8.0
# 2              159.0             39.00       1372.00     9.0
# 3               51.0             33.00       1100.00     9.0
# 4              125.0             55.00       1022.00     9.0
# 5               50.0            250.00       2050.00     9.4
# 6               56.0            290.00       2650.00     9.0
# 7               15.0             85.00       1457.00     9.2
# 8              152.0             41.00       1706.00     8.0
# 9              279.0            273.00       2500.00     9.4
# 10              96.0             62.00       2042.00     9.0
# 11             122.0             12.00        210.00     7.2
# 12               2.9              6.90        210.00     8.6
# 13              17.5             17.00         58.00     8.8
# 14              81.9              2.80       2042.16     8.8
# 15              24.0              7.00        216.00     8.2
# 16              16.9              6.90        505.00     8.4
# 17             170.0              5.00        763.00     9.0
# 18              15.0              6.00         50.00     8.2
# 19              37.0            115.00        733.00     7.6
# 20              22.0              2.00        598.00     8.2
# 21              12.0            315.00       2134.00     8.6
# 22              68.6             34.70       2100.00     8.6
# 23              22.0              7.00         14.00     7.8
# 24               7.0              4.00         45.00     8.2
# 25              70.0             38.00          2.00     9.0
# 26              67.0              1.78          3.00     9.0
# 27              63.0              9.00          4.00     9.6
# 28              33.0             15.00          2.00     9.0
# 29              60.0              3.00          5.00     8.8
# 30              46.0             21.00          5.00     8.0
# 31             142.0             23.40          5.00     9.0
# 32              24.0              8.00          5.00     8.0
# 33              18.0             12.00          5.00     9.0
# 34              60.0             16.00          5.00     8.8
# 35              63.0             15.00          5.00     9.2
# 36              64.0             35.30          2.00     9.2
# 37             125.0              1.50          2.00     9.4
# 38             228.0            110.00       3583.00     9.2
# 39             163.0              1.30         10.00     9.0
# 40              50.0             17.00       1585.00     9.0
# 41              11.9              2.00         14.00     9.4
# 42             311.0            318.00       3133.00     9.2
# 43             260.0            250.00       3100.00     9.4
# 44              25.0              6.00         81.00     9.2
# 45              60.0             28.00          1.00     9.2
# 46             210.0            175.00       3291.00     9.0
# 47              17.0              3.00        101.00     9.4
# 48              95.0            315.00       3888.00     8.8

# %% [markdown]
# ### to check the dimension

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# ###  to check how many rows and columns

# %%
df.shape
# Out:
# (49, 7)

# %% [markdown]
# ### to print fields name

# %%
df.columns
# Out:
# Index(['Name', 'Region', 'Type', 'airport_dist(km)', 'railway_dist(km)',
#        'Elevation(m)', 'rating'],
#       dtype='object')

# %% [markdown]
# ### to check the data type of attributes

# %%
df.dtypes
# Out:
# Name                 object
# Region               object
# Type                 object
# airport_dist(km)    float64
# railway_dist(km)    float64
# Elevation(m)        float64
# rating              float64
# dtype: object

# %% [markdown]
# ### to check the index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=49, step=1)

# %% [markdown]
# ### to view the top 5 records

# %%
df.head(5)
# Out:
#            Name      Region          Type  airport_dist(km)  railway_dist(km)  \
# 0         Kufri  North East  Hill Station              20.0             100.0
# 1  Wilson Hills        West  Hill Station             122.0              60.0
# 2   Paithalmala       South  Hill Station             159.0              39.0
# 3       Ponmudi       South  Hill Station              51.0              33.0
# 4     Ranipuram       South  Hill Station             125.0              55.0
#
#    Elevation(m)  rating
# 0        2210.0     7.0
# 1         750.0     8.0
# 2        1372.0     9.0
# 3        1100.0     9.0
# 4        1022.0     9.0

# %% [markdown]
# ### to view the last 5 records

# %%
df.tail(5)
# Out:
#                        Name      Region    Type  airport_dist(km)  \
# 44  Kashi Vishwanath Temple  North East  Temple              25.0
# 45    Lord Jagannath Temple  South East  Temple              60.0
# 46         Yamunotri Temple       North  Temple             210.0
# 47         Meenakshi Temple       South  Temple              17.0
# 48     Amarnath Cave Temple       North  Temple              95.0
#
#     railway_dist(km)  Elevation(m)  rating
# 44               6.0          81.0     9.2
# 45              28.0           1.0     9.2
# 46             175.0        3291.0     9.0
# 47               3.0         101.0     9.4
# 48             315.0        3888.0     8.8

# %% [markdown]
# ### to view any 5 random records

# %%
df.sample(5)
# Out:
#                            Name      Region             Type  \
# 10                   Darjeeling  North East     Hill Station
# 21                 Chattbir Zoo  North West  Zoological Park
# 13  Nandankanan Zoological Park        East  Zoological Park
# 47             Meenakshi Temple       South           Temple
# 19                 Gopalpur Zoo       North  Zoological Park
#
#     airport_dist(km)  railway_dist(km)  Elevation(m)  rating
# 10              96.0              62.0        2042.0     9.0
# 21              12.0             315.0        2134.0     8.6
# 13              17.5              17.0          58.0     8.8
# 47              17.0               3.0         101.0     9.4
# 19              37.0             115.0         733.0     7.6

# %% [markdown]
# ### to  print the region as index

# %%
df.set_index(['Region'])
# Out:
#                                                Name             Type  \
# Region
# North East                                    Kufri     Hill Station
# West                                   Wilson Hills     Hill Station
# South                                   Paithalmala     Hill Station
# South                                       Ponmudi     Hill Station
# South                                     Ranipuram     Hill Station
# North                                        Manali     Hill Station
# North                                       Gulmarg     Hill Station
# North East                              Dharamshala     Hill Station
# North East                                Lansdowne     Hill Station
# North East                                     Auli     Hill Station
# North East                               Darjeeling     Hill Station
# East               Jawaharlal Nehru Biological Park  Zoological Park
# East                     Tata Steel Zoological Park  Zoological Park
# East                    Nandankanan Zoological Park  Zoological Park
# East        Padmaja Naidu Himalayan Zoological Park  Zoological Park
# North                      National zooligical Park  Zoological Park
# South West                    Nehru Zoological Park  Zoological Park
# South West                               Mysore Zoo  Zoological Park
# South East             Arignar Anna Zoological Park  Zoological Park
# North                                  Gopalpur Zoo  Zoological Park
# North West                      Gulabh Bagh and Zoo  Zoological Park
# North West                             Chattbir Zoo  Zoological Park
# North                Pt. G.B Pant High Altitude Zoo  Zoological Park
# North East                              Alipore Zoo  Zoological Park
# South                 Indira Gandhi Zoological Park  Zoological Park
# West                                   Agonda beach            Beach
# East                                  Palolem Beach            Beach
# South East                         Radhanagar Beach            Beach
# West                               Cavelossim beach            Beach
# East                                     Puri Beach            Beach
# West                                 Candolim Beach            Beach
# West                              Dhanushkodi Beach            Beach
# West                                    Colva Beach            Beach
# West                                   Utorda Beach            Beach
# West                                   Marari Beach            Beach
# East                                Elephanta Beach            Beach
# East                          The Konark Sun Temple           Temple
# West                                 Somnath Temple           Temple
# North                              Kedarnath Temple           Temple
# South                          Ramnathaswamy Temple           Temple
# North                           Vaishno Devi Mandir           Temple
# West                           Siddhivinayak Temple           Temple
# North                              Badrinath Temple           Temple
# North                               Gangotri Temple           Temple
# North East                  Kashi Vishwanath Temple           Temple
# South East                    Lord Jagannath Temple           Temple
# North                              Yamunotri Temple           Temple
# South                              Meenakshi Temple           Temple
# North                          Amarnath Cave Temple           Temple
#
#             airport_dist(km)  railway_dist(km)  Elevation(m)  rating
# Region
# North East              20.0            100.00       2210.00     7.0
# West                   122.0             60.00        750.00     8.0
# South                  159.0             39.00       1372.00     9.0
# South                   51.0             33.00       1100.00     9.0
# South                  125.0             55.00       1022.00     9.0
# North                   50.0            250.00       2050.00     9.4
# North                   56.0            290.00       2650.00     9.0
# North East              15.0             85.00       1457.00     9.2
# North East             152.0             41.00       1706.00     8.0
# North East             279.0            273.00       2500.00     9.4
# North East              96.0             62.00       2042.00     9.0
# East                   122.0             12.00        210.00     7.2
# East                     2.9              6.90        210.00     8.6
# East                    17.5             17.00         58.00     8.8
# East                    81.9              2.80       2042.16     8.8
# North                   24.0              7.00        216.00     8.2
# South West              16.9              6.90        505.00     8.4
# South West             170.0              5.00        763.00     9.0
# South East              15.0              6.00         50.00     8.2
# North                   37.0            115.00        733.00     7.6
# North West              22.0              2.00        598.00     8.2
# North West              12.0            315.00       2134.00     8.6
# North                   68.6             34.70       2100.00     8.6
# North East              22.0              7.00         14.00     7.8
# South                    7.0              4.00         45.00     8.2
# West                    70.0             38.00          2.00     9.0
# East                    67.0              1.78          3.00     9.0
# South East              63.0              9.00          4.00     9.6
# West                    33.0             15.00          2.00     9.0
# East                    60.0              3.00          5.00     8.8
# West                    46.0             21.00          5.00     8.0
# West                   142.0             23.40          5.00     9.0
# West                    24.0              8.00          5.00     8.0
# West                    18.0             12.00          5.00     9.0
# West                    60.0             16.00          5.00     8.8
# East                    63.0             15.00          5.00     9.2
# East                    64.0             35.30          2.00     9.2
# West                   125.0              1.50          2.00     9.4
# North                  228.0            110.00       3583.00     9.2
# South                  163.0              1.30         10.00     9.0
# North                   50.0             17.00       1585.00     9.0
# West                    11.9              2.00         14.00     9.4
# North                  311.0            318.00       3133.00     9.2
# North                  260.0            250.00       3100.00     9.4
# North East              25.0              6.00         81.00     9.2
# South East              60.0             28.00          1.00     9.2
# North                  210.0            175.00       3291.00     9.0
# South                   17.0              3.00        101.00     9.4
# North                   95.0            315.00       3888.00     8.8

# %% [markdown]
# ### to check the information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              49 non-null     object
#  1   Region            49 non-null     object
#  2   Type              49 non-null     object
#  3   airport_dist(km)  49 non-null     float64
#  4   railway_dist(km)  49 non-null     float64
#  5   Elevation(m)      49 non-null     float64
#  6   rating            49 non-null     float64
# dtypes: float64(4), object(3)
# memory usage: 2.8+ KB

# %% [markdown]
# ### describing the data set

# %%
df.describe()
# Out:
#        airport_dist(km)  railway_dist(km)  Elevation(m)     rating
# count         49.000000         49.000000     49.000000  49.000000
# mean          81.830612         66.399592    966.819592   8.755102
# std           76.034154         98.195439   1174.458700   0.593388
# min            2.900000          1.300000      1.000000   7.000000
# 25%           22.000000          6.900000      5.000000   8.400000
# 50%           60.000000         17.000000    216.000000   9.000000
# 75%          122.000000         62.000000   2042.000000   9.200000
# max          311.000000        318.000000   3888.000000   9.600000

# %% [markdown]
# ### Descriptive statistics

# %%
df.describe(include='all')
# Out:
#                     Name Region             Type  airport_dist(km)  \
# count                 49     49               49         49.000000
# unique                49      8                4               NaN
# top     Badrinath Temple  North  Zoological Park               NaN
# freq                   1     11               14               NaN
# mean                 NaN    NaN              NaN         81.830612
# std                  NaN    NaN              NaN         76.034154
# min                  NaN    NaN              NaN          2.900000
# 25%                  NaN    NaN              NaN         22.000000
# 50%                  NaN    NaN              NaN         60.000000
# 75%                  NaN    NaN              NaN        122.000000
# max                  NaN    NaN              NaN        311.000000
#
#         railway_dist(km)  Elevation(m)     rating
# count          49.000000     49.000000  49.000000
# unique               NaN           NaN        NaN
# top                  NaN           NaN        NaN
# freq                 NaN           NaN        NaN
# mean           66.399592    966.819592   8.755102
# std            98.195439   1174.458700   0.593388
# min             1.300000      1.000000   7.000000
# 25%             6.900000      5.000000   8.400000
# 50%            17.000000    216.000000   9.000000
# 75%            62.000000   2042.000000   9.200000
# max           318.000000   3888.000000   9.600000

# %% [markdown]
# ### to detect any missing values in the dataset

# %%
df.isna().sum()
# Out:
# Name                0
# Region              0
# Type                0
# airport_dist(km)    0
# railway_dist(km)    0
# Elevation(m)        0
# rating              0
# dtype: int64

# %% [markdown]
# ## query to extract data from given dataframe

# %% [markdown]
# ### query for extracting the records of places in east

# %%
east_places=df.loc[df['Region']=='East']
east_places
# Out:
#                                        Name Region             Type  \
# 11         Jawaharlal Nehru Biological Park   East  Zoological Park
# 12               Tata Steel Zoological Park   East  Zoological Park
# 13              Nandankanan Zoological Park   East  Zoological Park
# 14  Padmaja Naidu Himalayan Zoological Park   East  Zoological Park
# 26                            Palolem Beach   East            Beach
# 29                               Puri Beach   East            Beach
# 35                          Elephanta Beach   East            Beach
# 36                    The Konark Sun Temple   East           Temple
#
#     airport_dist(km)  railway_dist(km)  Elevation(m)  rating
# 11             122.0             12.00        210.00     7.2
# 12               2.9              6.90        210.00     8.6
# 13              17.5             17.00         58.00     8.8
# 14              81.9              2.80       2042.16     8.8
# 26              67.0              1.78          3.00     9.0
# 29              60.0              3.00          5.00     8.8
# 35              63.0             15.00          5.00     9.2
# 36              64.0             35.30          2.00     9.2

# %% [markdown]
# ### query for extracting the record of places in west region

# %%
west_places=df.loc[df['Region']=='West']
west_places
# Out:
#                     Name Region          Type  airport_dist(km)  \
# 1           Wilson Hills   West  Hill Station             122.0
# 25          Agonda beach   West         Beach              70.0
# 28      Cavelossim beach   West         Beach              33.0
# 30        Candolim Beach   West         Beach              46.0
# 31     Dhanushkodi Beach   West         Beach             142.0
# 32           Colva Beach   West         Beach              24.0
# 33          Utorda Beach   West         Beach              18.0
# 34          Marari Beach   West         Beach              60.0
# 37        Somnath Temple   West        Temple             125.0
# 41  Siddhivinayak Temple   West        Temple              11.9
#
#     railway_dist(km)  Elevation(m)  rating
# 1               60.0         750.0     8.0
# 25              38.0           2.0     9.0
# 28              15.0           2.0     9.0
# 30              21.0           5.0     8.0
# 31              23.4           5.0     9.0
# 32               8.0           5.0     8.0
# 33              12.0           5.0     9.0
# 34              16.0           5.0     8.8
# 37               1.5           2.0     9.4
# 41               2.0          14.0     9.4

# %% [markdown]
# ### query for extracting the record of places in North West region

# %%
NW_place=df.loc[df['Region']=='North West']
NW_place
# Out:
#                    Name      Region             Type  airport_dist(km)  \
# 20  Gulabh Bagh and Zoo  North West  Zoological Park              22.0
# 21         Chattbir Zoo  North West  Zoological Park              12.0
#
#     railway_dist(km)  Elevation(m)  rating
# 20               2.0         598.0     8.2
# 21             315.0        2134.0     8.6

# %% [markdown]
# ### query for extracting the record of places in north east region

# %%
NE_df=df.loc[df['Region']=='North East']
NE_df
# Out:
#                        Name      Region             Type  airport_dist(km)  \
# 0                     Kufri  North East     Hill Station              20.0
# 7               Dharamshala  North East     Hill Station              15.0
# 8                 Lansdowne  North East     Hill Station             152.0
# 9                      Auli  North East     Hill Station             279.0
# 10               Darjeeling  North East     Hill Station              96.0
# 23              Alipore Zoo  North East  Zoological Park              22.0
# 44  Kashi Vishwanath Temple  North East           Temple              25.0
#
#     railway_dist(km)  Elevation(m)  rating
# 0              100.0        2210.0     7.0
# 7               85.0        1457.0     9.2
# 8               41.0        1706.0     8.0
# 9              273.0        2500.0     9.4
# 10              62.0        2042.0     9.0
# 23               7.0          14.0     7.8
# 44               6.0          81.0     9.2

# %% [markdown]
# ### query for extracting the record of places in north region

# %%
North_df=df.loc[df['Region']=='North']
North_df
# Out:
#                               Name Region             Type  airport_dist(km)  \
# 5                           Manali  North     Hill Station              50.0
# 6                          Gulmarg  North     Hill Station              56.0
# 15        National zooligical Park  North  Zoological Park              24.0
# 19                    Gopalpur Zoo  North  Zoological Park              37.0
# 22  Pt. G.B Pant High Altitude Zoo  North  Zoological Park              68.6
# 38                Kedarnath Temple  North           Temple             228.0
# 40             Vaishno Devi Mandir  North           Temple              50.0
# 42                Badrinath Temple  North           Temple             311.0
# 43                 Gangotri Temple  North           Temple             260.0
# 46                Yamunotri Temple  North           Temple             210.0
# 48            Amarnath Cave Temple  North           Temple              95.0
#
#     railway_dist(km)  Elevation(m)  rating
# 5              250.0        2050.0     9.4
# 6              290.0        2650.0     9.0
# 15               7.0         216.0     8.2
# 19             115.0         733.0     7.6
# 22              34.7        2100.0     8.6
# 38             110.0        3583.0     9.2
# 40              17.0        1585.0     9.0
# 42             318.0        3133.0     9.2
# 43             250.0        3100.0     9.4
# 46             175.0        3291.0     9.0
# 48             315.0        3888.0     8.8

# %% [markdown]
# ### query for extracting the record of places in south region

# %%
south_df=df.loc[df['Region']=='South']
south_df
# Out:
#                              Name Region  airport_dist(km)  railway_dist(km)  \
# 2                     Paithalmala  South             159.0              39.0
# 3                         Ponmudi  South              51.0              33.0
# 4                       Ranipuram  South             125.0              55.0
# 24  Indira Gandhi Zoological Park  South               7.0               4.0
# 39           Ramnathaswamy Temple  South             163.0               1.3
# 47               Meenakshi Temple  South              17.0               3.0
#
#     Elevation(m)  rating
# 2         1372.0     9.0
# 3         1100.0     9.0
# 4         1022.0     9.0
# 24          45.0     8.2
# 39          10.0     9.0
# 47         101.0     9.4

# %% [markdown]
# ### query for extracting the record of places in south east region

# %%
se_df=df.loc[df['Region']=='South East']
se_df
# Out:
#                             Name      Region             Type  \
# 18  Arignar Anna Zoological Park  South East  Zoological Park
# 27              Radhanagar Beach  South East            Beach
# 45         Lord Jagannath Temple  South East           Temple
#
#     airport_dist(km)  railway_dist(km)  Elevation(m)  rating
# 18              15.0               6.0          50.0     8.2
# 27              63.0               9.0           4.0     9.6
# 45              60.0              28.0           1.0     9.2

# %% [markdown]
# ### query for extracting the record of places in south west region

# %%
sw_df=df.loc[df['Region']=='South West']
sw_df
# Out:
#                      Name      Region             Type  airport_dist(km)  \
# 16  Nehru Zoological Park  South West  Zoological Park              16.9
# 17             Mysore Zoo  South West  Zoological Park             170.0
#
#     railway_dist(km)  Elevation(m)  rating
# 16               6.9         505.0     8.4
# 17               5.0         763.0     9.0

# %% [markdown]
# ### query for extracting the record of hill station in india

# %%
hill_station =df.loc[df['Type']=='Hill Station']
hill_station
# Out:
#             Name      Region          Type  airport_dist(km)  \
# 0          Kufri  North East  Hill Station              20.0
# 1   Wilson Hills        West  Hill Station             122.0
# 2    Paithalmala       South  Hill Station             159.0
# 3        Ponmudi       South  Hill Station              51.0
# 4      Ranipuram       South  Hill Station             125.0
# 5         Manali       North  Hill Station              50.0
# 6        Gulmarg       North  Hill Station              56.0
# 7    Dharamshala  North East  Hill Station              15.0
# 8      Lansdowne  North East  Hill Station             152.0
# 9           Auli  North East  Hill Station             279.0
# 10    Darjeeling  North East  Hill Station              96.0
#
#     railway_dist(km)  Elevation(m)  rating
# 0              100.0        2210.0     7.0
# 1               60.0         750.0     8.0
# 2               39.0        1372.0     9.0
# 3               33.0        1100.0     9.0
# 4               55.0        1022.0     9.0
# 5              250.0        2050.0     9.4
# 6              290.0        2650.0     9.0
# 7               85.0        1457.0     9.2
# 8               41.0        1706.0     8.0
# 9              273.0        2500.0     9.4
# 10              62.0        2042.0     9.0

# %% [markdown]
# ### query for extracting the record of Zoological Park in india

# %%
zoo_park=df.loc[df['Type']=='Zoological Park']
zoo_park
# Out:
#                                        Name      Region             Type  \
# 11         Jawaharlal Nehru Biological Park        East  Zoological Park
# 12               Tata Steel Zoological Park        East  Zoological Park
# 13              Nandankanan Zoological Park        East  Zoological Park
# 14  Padmaja Naidu Himalayan Zoological Park        East  Zoological Park
# 15                 National zooligical Park       North  Zoological Park
# 16                    Nehru Zoological Park  South West  Zoological Park
# 17                               Mysore Zoo  South West  Zoological Park
# 18             Arignar Anna Zoological Park  South East  Zoological Park
# 19                             Gopalpur Zoo       North  Zoological Park
# 20                      Gulabh Bagh and Zoo  North West  Zoological Park
# 21                             Chattbir Zoo  North West  Zoological Park
# 22           Pt. G.B Pant High Altitude Zoo       North  Zoological Park
# 23                              Alipore Zoo  North East  Zoological Park
# 24            Indira Gandhi Zoological Park       South  Zoological Park
#
#     airport_dist(km)  railway_dist(km)  Elevation(m)  rating
# 11             122.0              12.0        210.00     7.2
# 12               2.9               6.9        210.00     8.6
# 13              17.5              17.0         58.00     8.8
# 14              81.9               2.8       2042.16     8.8
# 15              24.0               7.0        216.00     8.2
# 16              16.9               6.9        505.00     8.4
# 17             170.0               5.0        763.00     9.0
# 18              15.0               6.0         50.00     8.2
# 19              37.0             115.0        733.00     7.6
# 20              22.0               2.0        598.00     8.2
# 21              12.0             315.0       2134.00     8.6
# 22              68.6              34.7       2100.00     8.6
# 23              22.0               7.0         14.00     7.8
# 24               7.0               4.0         45.00     8.2

# %% [markdown]
# ### query for extracting the record of  temple in india

# %%
temple=df.loc[df['Type']=='Temple']
temple
# Out:
#                        Name      Region    Type  airport_dist(km)  \
# 36    The Konark Sun Temple        East  Temple              64.0
# 37           Somnath Temple        West  Temple             125.0
# 38         Kedarnath Temple       North  Temple             228.0
# 39     Ramnathaswamy Temple       South  Temple             163.0
# 40      Vaishno Devi Mandir       North  Temple              50.0
# 41     Siddhivinayak Temple        West  Temple              11.9
# 42         Badrinath Temple       North  Temple             311.0
# 43          Gangotri Temple       North  Temple             260.0
# 44  Kashi Vishwanath Temple  North East  Temple              25.0
# 45    Lord Jagannath Temple  South East  Temple              60.0
# 46         Yamunotri Temple       North  Temple             210.0
# 47         Meenakshi Temple       South  Temple              17.0
# 48     Amarnath Cave Temple       North  Temple              95.0
#
#     railway_dist(km)  Elevation(m)  rating
# 36              35.3           2.0     9.2
# 37               1.5           2.0     9.4
# 38             110.0        3583.0     9.2
# 39               1.3          10.0     9.0
# 40              17.0        1585.0     9.0
# 41               2.0          14.0     9.4
# 42             318.0        3133.0     9.2
# 43             250.0        3100.0     9.4
# 44               6.0          81.0     9.2
# 45              28.0           1.0     9.2
# 46             175.0        3291.0     9.0
# 47               3.0         101.0     9.4
# 48             315.0        3888.0     8.8

# %% [markdown]
# ### query for extracting the record of  beach in india

# %%
##query for extracting the record of  beach in india###
beach=df.loc[df['Type']=='Beach']
beach
# Out:
#                  Name      Region   Type  airport_dist(km)  railway_dist(km)  \
# 25       Agonda beach        West  Beach              70.0             38.00
# 26      Palolem Beach        East  Beach              67.0              1.78
# 27   Radhanagar Beach  South East  Beach              63.0              9.00
# 28   Cavelossim beach        West  Beach              33.0             15.00
# 29         Puri Beach        East  Beach              60.0              3.00
# 30     Candolim Beach        West  Beach              46.0             21.00
# 31  Dhanushkodi Beach        West  Beach             142.0             23.40
# 32        Colva Beach        West  Beach              24.0              8.00
# 33       Utorda Beach        West  Beach              18.0             12.00
# 34       Marari Beach        West  Beach              60.0             16.00
# 35    Elephanta Beach        East  Beach              63.0             15.00
#
#     Elevation(m)  rating
# 25           2.0     9.0
# 26           3.0     9.0
# 27           4.0     9.6
# 28           2.0     9.0
# 29           5.0     8.8
# 30           5.0     8.0
# 31           5.0     9.0
# 32           5.0     8.0
# 33           5.0     9.0
# 34           5.0     8.8
# 35           5.0     9.2

# %% [markdown]
# ### query to extract the record of places whose rating is greater than 9

# %%
df[df['rating'] >9]
# Out:
#                        Name      Region          Type  airport_dist(km)  \
# 5                    Manali       North  Hill Station              50.0
# 7               Dharamshala  North East  Hill Station              15.0
# 9                      Auli  North East  Hill Station             279.0
# 27         Radhanagar Beach  South East         Beach              63.0
# 35          Elephanta Beach        East         Beach              63.0
# 36    The Konark Sun Temple        East        Temple              64.0
# 37           Somnath Temple        West        Temple             125.0
# 38         Kedarnath Temple       North        Temple             228.0
# 41     Siddhivinayak Temple        West        Temple              11.9
# 42         Badrinath Temple       North        Temple             311.0
# 43          Gangotri Temple       North        Temple             260.0
# 44  Kashi Vishwanath Temple  North East        Temple              25.0
# 45    Lord Jagannath Temple  South East        Temple              60.0
# 47         Meenakshi Temple       South        Temple              17.0
#
#     railway_dist(km)  Elevation(m)  rating
# 5              250.0        2050.0     9.4
# 7               85.0        1457.0     9.2
# 9              273.0        2500.0     9.4
# 27               9.0           4.0     9.6
# 35              15.0           5.0     9.2
# 36              35.3           2.0     9.2
# 37               1.5           2.0     9.4
# 38             110.0        3583.0     9.2
# 41               2.0          14.0     9.4
# 42             318.0        3133.0     9.2
# 43             250.0        3100.0     9.4
# 44               6.0          81.0     9.2
# 45              28.0           1.0     9.2
# 47               3.0         101.0     9.4

# %% [markdown]
# ### query to extract the record of places whose rating is less than 8

# %%
df[df['rating']<8]
# Out:
#                                 Name      Region             Type  \
# 0                              Kufri  North East     Hill Station
# 11  Jawaharlal Nehru Biological Park        East  Zoological Park
# 19                      Gopalpur Zoo       North  Zoological Park
# 23                       Alipore Zoo  North East  Zoological Park
#
#     airport_dist(km)  railway_dist(km)  Elevation(m)  rating
# 0               20.0             100.0        2210.0     7.0
# 11             122.0              12.0         210.0     7.2
# 19              37.0             115.0         733.0     7.6
# 23              22.0               7.0          14.0     7.8

# %% [markdown]
# ### query to extract the record of places whose airport distance is less than or equal to 30 km

# %%
df[df['airport_dist(km)']<=30]
# Out:
#                              Name      Region             Type  \
# 0                           Kufri  North East     Hill Station
# 7                     Dharamshala  North East     Hill Station
# 12     Tata Steel Zoological Park        East  Zoological Park
# 13    Nandankanan Zoological Park        East  Zoological Park
# 15       National zooligical Park       North  Zoological Park
# 16          Nehru Zoological Park  South West  Zoological Park
# 18   Arignar Anna Zoological Park  South East  Zoological Park
# 20            Gulabh Bagh and Zoo  North West  Zoological Park
# 21                   Chattbir Zoo  North West  Zoological Park
# 23                    Alipore Zoo  North East  Zoological Park
# 24  Indira Gandhi Zoological Park       South  Zoological Park
# 32                    Colva Beach        West            Beach
# 33                   Utorda Beach        West            Beach
# 41           Siddhivinayak Temple        West           Temple
# 44        Kashi Vishwanath Temple  North East           Temple
# 47               Meenakshi Temple       South           Temple
#
#     airport_dist(km)  railway_dist(km)  Elevation(m)  rating
# 0               20.0             100.0        2210.0     7.0
# 7               15.0              85.0        1457.0     9.2
# 12               2.9               6.9         210.0     8.6
# 13              17.5              17.0          58.0     8.8
# 15              24.0               7.0         216.0     8.2
# 16              16.9               6.9         505.0     8.4
# 18              15.0               6.0          50.0     8.2
# 20              22.0               2.0         598.0     8.2
# 21              12.0             315.0        2134.0     8.6
# 23              22.0               7.0          14.0     7.8
# 24               7.0               4.0          45.0     8.2
# 32              24.0               8.0           5.0     8.0
# 33              18.0              12.0           5.0     9.0
# 41              11.9               2.0          14.0     9.4
# 44              25.0               6.0          81.0     9.2
# 47              17.0               3.0         101.0     9.4

# %% [markdown]
# ### query to extract the record of places whose railway distance is less than or equal to 5 km

# %%
df[df['railway_dist(km)']<=5]
# Out:
#                                        Name      Region             Type  \
# 14  Padmaja Naidu Himalayan Zoological Park        East  Zoological Park
# 17                               Mysore Zoo  South West  Zoological Park
# 20                      Gulabh Bagh and Zoo  North West  Zoological Park
# 24            Indira Gandhi Zoological Park       South  Zoological Park
# 26                            Palolem Beach        East            Beach
# 29                               Puri Beach        East            Beach
# 37                           Somnath Temple        West           Temple
# 39                     Ramnathaswamy Temple       South           Temple
# 41                     Siddhivinayak Temple        West           Temple
# 47                         Meenakshi Temple       South           Temple
#
#     airport_dist(km)  railway_dist(km)  Elevation(m)  rating
# 14              81.9              2.80       2042.16     8.8
# 17             170.0              5.00        763.00     9.0
# 20              22.0              2.00        598.00     8.2
# 24               7.0              4.00         45.00     8.2
# 26              67.0              1.78          3.00     9.0
# 29              60.0              3.00          5.00     8.8
# 37             125.0              1.50          2.00     9.4
# 39             163.0              1.30         10.00     9.0
# 41              11.9              2.00         14.00     9.4
# 47              17.0              3.00        101.00     9.4

# %% [markdown]
# ### query for extracting the record of places having elevation is 5 m

# %%
elv=df.loc[df['Elevation(m)']==5.0]
elv
# Out:
#                  Name Region   Type  airport_dist(km)  railway_dist(km)  \
# 29         Puri Beach   East  Beach              60.0               3.0
# 30     Candolim Beach   West  Beach              46.0              21.0
# 31  Dhanushkodi Beach   West  Beach             142.0              23.4
# 32        Colva Beach   West  Beach              24.0               8.0
# 33       Utorda Beach   West  Beach              18.0              12.0
# 34       Marari Beach   West  Beach              60.0              16.0
# 35    Elephanta Beach   East  Beach              63.0              15.0
#
#     Elevation(m)  rating
# 29           5.0     8.8
# 30           5.0     8.0
# 31           5.0     9.0
# 32           5.0     8.0
# 33           5.0     9.0
# 34           5.0     8.8
# 35           5.0     9.2

# %% [markdown]
# ### query for extracting the record of places having elevation greater than 2000 m.

# %%
elv1=df.loc[df['Elevation(m)']>2000]
elv1
# Out:
#                                        Name      Region             Type  \
# 0                                     Kufri  North East     Hill Station
# 5                                    Manali       North     Hill Station
# 6                                   Gulmarg       North     Hill Station
# 9                                      Auli  North East     Hill Station
# 10                               Darjeeling  North East     Hill Station
# 14  Padmaja Naidu Himalayan Zoological Park        East  Zoological Park
# 21                             Chattbir Zoo  North West  Zoological Park
# 22           Pt. G.B Pant High Altitude Zoo       North  Zoological Park
# 38                         Kedarnath Temple       North           Temple
# 42                         Badrinath Temple       North           Temple
# 43                          Gangotri Temple       North           Temple
# 46                         Yamunotri Temple       North           Temple
# 48                     Amarnath Cave Temple       North           Temple
#
#     airport_dist(km)  railway_dist(km)  Elevation(m)  rating
# 0               20.0             100.0       2210.00     7.0
# 5               50.0             250.0       2050.00     9.4
# 6               56.0             290.0       2650.00     9.0
# 9              279.0             273.0       2500.00     9.4
# 10              96.0              62.0       2042.00     9.0
# 14              81.9               2.8       2042.16     8.8
# 21              12.0             315.0       2134.00     8.6
# 22              68.6              34.7       2100.00     8.6
# 38             228.0             110.0       3583.00     9.2
# 42             311.0             318.0       3133.00     9.2
# 43             260.0             250.0       3100.00     9.4
# 46             210.0             175.0       3291.00     9.0
# 48              95.0             315.0       3888.00     8.8

# %% [markdown]
# ### query to extract the unique values from the data set

# %% [markdown]
# ### unique values from name

# %%
unq_name=df.Name.unique()
unq_name
# Out:
# array(['Kufri', 'Wilson Hills', 'Paithalmala', 'Ponmudi', 'Ranipuram',
#        'Manali', 'Gulmarg', 'Dharamshala', 'Lansdowne', 'Auli',
#        'Darjeeling', 'Jawaharlal Nehru Biological Park',
#        'Tata Steel Zoological Park', 'Nandankanan Zoological Park',
#        'Padmaja Naidu Himalayan Zoological Park',
#        'National zooligical Park', 'Nehru Zoological Park', 'Mysore Zoo',
#        'Arignar Anna Zoological Park', 'Gopalpur Zoo',
#        'Gulabh Bagh and Zoo', 'Chattbir Zoo',
#        'Pt. G.B Pant High Altitude Zoo', 'Alipore Zoo',
#        'Indira Gandhi Zoological Park', 'Agonda beach', 'Palolem Beach',
#        'Radhanagar Beach', 'Cavelossim beach', 'Puri Beach',
#        'Candolim Beach', 'Dhanushkodi Beach', 'Colva Beach',
#        'Utorda Beach', 'Marari Beach', 'Elephanta Beach',
#        'The Konark Sun Temple', 'Somnath Temple', 'Kedarnath Temple',
#        'Ramnathaswamy Temple', 'Vaishno Devi Mandir',
#        'Siddhivinayak Temple', 'Badrinath Temple', 'Gangotri Temple',
#        'Kashi Vishwanath Temple', 'Lord Jagannath Temple',
#        'Yamunotri Temple', 'Meenakshi Temple', 'Amarnath Cave Temple'],
#       dtype=object)

# %% [markdown]
# ### unique values from type

# %%
unq_typ=df.Type.unique()
unq_typ
# Out:
# array(['Hill Station', 'Zoological Park', 'Beach', 'Temple'], dtype=object)

# %% [markdown]
# ### unique values from region

# %%
unq_Region=df.Region.unique()
unq_Region
# Out:
# array(['North East', 'West', 'South', 'North', 'East', 'South West',
#        'South East', 'North West'], dtype=object)

# %% [markdown]
# ### unique values from rating

# %%
unq_ratng=df.rating.unique()
unq_ratng
# Out:
# array([7. , 8. , 9. , 9.4, 9.2, 7.2, 8.6, 8.8, 8.2, 8.4, 7.6, 7.8, 9.6])

# %% [markdown]
# ## Descriptive statistics

# %% [markdown]
# ### to calculate the mean,median,maximum,minimum,variance,standard deviation of the airport distance(km) from the data set

# %%
air_mean=df['airport_dist(km)'].mean()
air_mean
# Out:
# 81.83061224489796

# %%
air_median=df['airport_dist(km)'].median()
air_median
# Out:
# 60.0

# %%
air_maxm=df['airport_dist(km)'].max()
air_maxm
# Out:
# 311.0

# %%
air_minm=df['airport_dist(km)'].min()
air_minm
# Out:
# 2.9

# %%
air_variance=df['airport_dist(km)'].var()
air_variance
# Out:
# 5781.192585034012

# %%
air_sd=df['airport_dist(km)'].std()
air_sd
# Out:
# 76.03415406929976

# %% [markdown]
# ### to calculate the mean,median,maximum,minimum,variance,standard deviation of the railway distance(km) from the data set

# %%
rail_mean=df['railway_dist(km)'].mean()
rail_mean
# Out:
# 66.3995918367347

# %%
rail_median=df['railway_dist(km)'].median()
rail_median
# Out:
# 17.0

# %%
rail_max=df['railway_dist(km)'].max()
rail_max
# Out:
# 318.0

# %%
rail_min=df['railway_dist(km)'].min()
rail_min
# Out:
# 1.3

# %%
rail_variance=df['railway_dist(km)'].var()
rail_variance
# Out:
# 9642.344258163266

# %%
rail_SD=df['railway_dist(km)'].std()
rail_SD
# Out:
# 98.19543909043468

# %% [markdown]
# ### to calculate the mean,median,maximum,minimum,variance,standard deviation of the Elevation(m) from the data set

# %%
elv_mean=df['Elevation(m)'].mean()
elv_mean
# Out:
# 966.8195918367347

# %%
elv_median=df['Elevation(m)'].median()
elv_median
# Out:
# 216.0

# %%
elv_max=df['Elevation(m)'].max()
elv_max
# Out:
# 3888.0

# %%
elv_min=df['Elevation(m)'].min()
elv_min
# Out:
# 1.0

# %%
elv_variance=df['Elevation(m)'].var()
elv_variance
# Out:
# 1379353.2381414967

# %%
elv_SD=df['Elevation(m)'].std()
elv_SD
# Out:
# 1174.4587000578167

# %% [markdown]
# ### to calculate the mean,median,maximum,minimum,variance,standard deviation of the Rating from the data set

# %%
ra_mean=df['rating'].mean()
ra_mean
# Out:
# 8.755102040816324

# %%
ra_median=df['rating'].median()
ra_median
# Out:
# 9.0

# %%
ra_max=df['rating'].max()
ra_max
# Out:
# 9.6

# %%
ra_min=df['rating'].min()
ra_min
# Out:
# 7.0

# %%
ra_variance=df['rating'].var()
ra_variance
# Out:
# 0.3521088435374152

# %%
ra_sd=df['rating'].std()
ra_sd
# Out:
# 0.5933875997502941

# %% [markdown]
# ## VISUALIZATION

# %% [markdown]
# # plotting the graph

# %%
style.use('ggplot')
bins=[7,7.5,8,8.5,9,9.5,10]
plt.hist(df['rating'],bins,histtype='bar',color='m',rwidth=.6)
plt.xlabel('range')
plt.ylabel('RATINGS')
plt.title('INDIAN TOURISM')
plt.show()

# %% [markdown]
# ## graph plotting of rating &  places in india

# %%
plt.figure(figsize=(10,12))
sns.barplot(x='rating',
            y='Name',
            data=df)
plt.xlabel('RATING')
plt.ylabel('TOURIST PLACES')
plt.title("TOURISM RATING IN INDIA")
plt.show()

# %% [markdown]
# ## plotting the graph based on the transportation of india

# %%
plt.style.use('seaborn-darkgrid')
x=df['Name']
y=df['airport_dist(km)']
y1=df['railway_dist(km)']

plt.figure(figsize=(10,12))
plt.barh(x,y,label='airport_dist(km)',color='g')
plt.barh(x,y1,label='railway_dist(km)',left=y,color='y')

plt.xlabel('Name of places')
plt.ylabel('distance')
plt.title(' INFORMATION ABOUT TRANSPORTATION')
plt.legend()
plt.show()

# %% [markdown]
# ## Count the number of regions where places are located

# %%
sns.set(style="darkgrid")
sns.countplot(x='Region',data=df)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %% [markdown]
# ## count the types of places from dataset

# %%
sns.countplot(x='Type',data=df)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %% [markdown]
# ##  graph plotting  for airport distances of places in india from dataset

# %%
sns.distplot(df['airport_dist(km)'])
# Out:
# <AxesSubplot:xlabel='airport_dist(km)', ylabel='Density'>

# %% [markdown]
# ##  graph plotting  for railway distances  of places in india from dataset

# %%
sns.distplot(df['railway_dist(km)'])
# Out:
# <AxesSubplot:xlabel='railway_dist(km)', ylabel='Density'>

# %% [markdown]
# ## plot to display the distribution for rating with respect to each types of places in india

# %%
sns.barplot(x='Type',y="rating",data=df)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='rating'>

# %%
sns.boxplot(x='Type',y='rating',data=df)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='rating'>

# %%
sns.stripplot(x='Type',y='rating',data=df)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='rating'>

# %% [markdown]
# ## plot to display the distribution for rating with respect to each regions

# %%
sns.violinplot(x='Region',y='rating',data=df)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='rating'>

# %%
sns.swarmplot(x='Region',y='rating',data=df)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='rating'>

# %% [markdown]
# ## Conclusion

# %%
  We have done exploratory analysis on the tourism of india.Analysed and queried to extract the record of places have highest 
rating and lowest rating in india.From Visualization , it is clear that Radhanagar Beach has the highest rating among the tourist 
places in  india.Kufri has the lowest rating based on the analysis .

# %% [markdown]
# ## Reference

# %%
1. www.kaggle.com

2. https://encyclopedia.com
